# %% [markdown]
# Dataset: Haberman survival dataset
#
# Description: The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Attribute Information:
#
# Age of patient at time of operation (numerical)
# Patient's year of operation (year - 1900, numerical)
# Number of positive axillary nodes detected (numerical) :A positive axillary lymph node is a lymph node in the area of the armpit (axilla) to which cancer has spread. This spread is determined by surgically removing some of the lymph nodes and examining them under a microscope to see whether cancer cells are present. #ref https://en.wikipedia.org/wiki/Positive_axillary_lymph_node
# Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
#
# Objective: Performing exploratoy data anlysis on Haberman dataset

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating a dataframe using csv file
hab = pd.read_csv('haberman.csv')

# %%
hab.head()
# Out:
#    age  year_of_operation  p_axillary_nodes  survival_status
# 0   30                 64                 1                1
# 1   30                 62                 3                1
# 2   30                 65                 0                1
# 3   31                 59                 2                1
# 4   31                 65                 4                1

# %%
hab.count()
# Out:
# age                  306
# year_of_operation    306
# p_axillary_nodes     306
# survival_status      306
# dtype: int64

# %%
hab['survival_status'].value_counts()
#Its an imbalanced class,survived patients of #225 and patients unable to survive within 5 years of #81
# Out:
# 1    225
# 2     81
# Name: survival_status, dtype: int64

# %%
print(hab.columns)
# Out:
# Index(['age', 'year_of_operation', 'p_axillary_nodes', 'survival_status'], dtype='object')

# %% [markdown]
# ### Mean,Median,Std Dev and Mad Comparision

# %%
hab.describe()
# Out:
#               age  year_of_operation  p_axillary_nodes  survival_status
# count  306.000000         306.000000        306.000000       306.000000
# mean    52.457516          62.852941          4.026144         1.264706
# std     10.803452           3.249405          7.189654         0.441899
# min     30.000000          58.000000          0.000000         1.000000
# 25%     44.000000          60.000000          0.000000         1.000000
# 50%     52.000000          63.000000          1.000000         1.000000
# 75%     60.750000          65.750000          4.000000         2.000000
# max     83.000000          69.000000         52.000000         2.000000

# %%
print(hab['age'].median())
print(hab['year_of_operation'].median())
print(hab['p_axillary_nodes'].median())
print(hab['age'].mad())
print(hab['year_of_operation'].mad())
print(hab['p_axillary_nodes'].mad())
##By comparing mean,std dev of all the three features with corresponding median and mad,
##we can see p_axillary nodes show high difference in values.we can say p_axillary_nodes got outliers.
# Out:
# 52.0
# 63.0
# 1.0
# 8.865180058951662
# 2.7870049980776614
# 4.790935110427601

# %% [markdown]
# ### Scatter Plots

# %%
hab.plot(kind='scatter',x = 'age', y = 'year_of_operation' )
plt.show()

# %%
d = {'color': ['g', 'r']}
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue='survival_status', hue_kws=d, size=4) \
   .map(plt.scatter, 'age', 'year_of_operation') \
   .add_legend();
plt.show()

#This looks like a messy dataset.With the help of age and year of operation we are not able to get any patterns.

# %%
d = {'color': ['g', 'r']}
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue='survival_status', hue_kws=d, size=4) \
   .map(plt.scatter, 'year_of_operation', 'survival_status') \
   .add_legend();
plt.show()

# %%
d = {'color': ['g', 'r']}
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue='survival_status', hue_kws=d, size=4) \
   .map(plt.scatter, 'p_axillary_nodes', 'survival_status') \
   .add_legend();
plt.show()

# %%
d = {'color': ['g', 'r']}
sns.set_style("whitegrid");
sns.FacetGrid(hab, hue='survival_status', hue_kws=d, size=4) \
   .map(plt.scatter, 'age', 'survival_status') \
   .add_legend();
plt.show()

# %%
##hab_1 = hab.drop(['survival_status'],axis =1)
##hab_1.head()

# %%
#PairPlot
k ={"1":"green","2":"red"}
sns.set_style("whitegrid");
sns.pairplot(hab, hue="survival_status", vars = ['age','year_of_operation','p_axillary_nodes'],size=3);
plt.show()
#the data looks clumsy.

# %%
hab_status1 = hab.loc[hab['survival_status'] == 1]
hab_status2 = hab.loc[hab['survival_status'] == 2]
plt.plot(hab_status1['age'],np.zeros_like(hab_status1['age']),'o')
plt.plot(hab_status2['age'],np.zeros_like(hab_status2['age']),'o')
plt.show()
##Division of dataset into two dataframes based on survival status

# %%
hab_status1.head()
# Out:
#    age  year_of_operation  p_axillary_nodes  survival_status
# 0   30                 64                 1                1
# 1   30                 62                 3                1
# 2   30                 65                 0                1
# 3   31                 59                 2                1
# 4   31                 65                 4                1

# %%
print(hab['year_of_operation'].value_counts())
print(hab_status1['year_of_operation'].value_counts())
print(hab_status2['year_of_operation'].value_counts())
# Out:
# 58    36
# 64    31
# 63    30
# 66    28
# 65    28
# 60    28
# 59    27
# 61    26
# 67    25
# 62    23
# 68    13
# 69    11
# Name: year_of_operation, dtype: int64
# 60    24
# 58    24
# 64    23
# 61    23
# 66    22
# 63    22
# 67    21
# 59    18
# 62    16
# 65    15
# 68    10
# 69     7
# Name: year_of_operation, dtype: int64
# 65    13
# 58    12
# 59     9
# 64     8
# 63     8
# 62     7
# 66     6
# 69     4
# 67     4
# 60     4
# 68     3
# 61     3
# Name: year_of_operation, dtype: int64

# %%
plt.plot(hab_status1['year_of_operation'],np.zeros_like(hab_status1['age']),'o')
plt.plot(hab_status2['year_of_operation'],np.zeros_like(hab_status2['age']),'*')
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
#Histogram
sns.FacetGrid(hab, hue='survival_status', size=5) \
   .map(sns.distplot, "age",)\
   .add_legend();
plt.show();
#Highest number of survivals exist between 50 and 55,similarly 40 to 45 for unsurvived.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-836df82931d5> in <module>()
#       1 #Histogram
#       2 sns.FacetGrid(hab, hue='survival_status', size=5)    .map(sns.distplot, "age",)   .add_legend();
# ----> 3 plt.show();g
#
# NameError: name 'g' is not defined

# %%
sns.FacetGrid(hab, hue='survival_status', size=5) \
   .map(sns.distplot, "year_of_operation") \
   .add_legend();
plt.show();
#Highest number of survivals had been operated between approx 60 to 61,similarly 63 to 66 for unsurvived.

# %%
sns.FacetGrid(hab, hue='survival_status', size=5) \
   .map(sns.distplot, "p_axillary_nodes") \
   .add_legend();
plt.show();
#More than 50% of the survivals have n_axilliary_nodes as zero.As the n_axilliary_nodes increased survival rate drastically decreased.

# %%
print(hab_status1.describe())
print(hab_status2.describe())
# Out:
#               age  year_of_operation  p_axillary_nodes  survival_status
# count  225.000000         225.000000        225.000000            225.0
# mean    52.017778          62.862222          2.791111              1.0
# std     11.012154           3.222915          5.870318              0.0
# min     30.000000          58.000000          0.000000              1.0
# 25%     43.000000          60.000000          0.000000              1.0
# 50%     52.000000          63.000000          0.000000              1.0
# 75%     60.000000          66.000000          3.000000              1.0
# max     77.000000          69.000000         46.000000              1.0
#              age  year_of_operation  p_axillary_nodes  survival_status
# count  81.000000          81.000000         81.000000             81.0
# mean   53.679012          62.827160          7.456790              2.0
# std    10.167137           3.342118          9.185654              0.0
# ...

# %% [markdown]
# ### CDF

# %%
##survivalstatus1(green) vs survival status2(red)
counts, bin_edges = np.histogram(hab_status1['age'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color = 'green');
plt.plot(bin_edges[1:], cdf,color = 'green')


counts, bin_edges = np.histogram(hab_status2['age'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color='red');
plt.plot(bin_edges[1:], cdf,color = 'red')
plt.show();

#
# Out:
# [ 0.05333333  0.10666667  0.12444444  0.09333333  0.16444444  0.16444444
#   0.09333333  0.11111111  0.06222222  0.02666667]
# [ 30.   34.7  39.4  44.1  48.8  53.5  58.2  62.9  67.6  72.3  77. ]
# [ 0.03703704  0.12345679  0.19753086  0.19753086  0.13580247  0.12345679
#   0.09876543  0.04938272  0.02469136  0.01234568]
# [ 34.   38.9  43.8  48.7  53.6  58.5  63.4  68.3  73.2  78.1  83. ]

# %%
##survivalstatus1(green) vs survival status2(red)
counts, bin_edges = np.histogram(hab_status1['year_of_operation'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color = 'green');
plt.plot(bin_edges[1:], cdf,color = 'green')


counts, bin_edges = np.histogram(hab_status2['year_of_operation'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color='red');
plt.plot(bin_edges[1:], cdf,color = 'red')
plt.show();
# Out:
# [ 0.18666667  0.10666667  0.10222222  0.07111111  0.09777778  0.10222222
#   0.06666667  0.09777778  0.09333333  0.07555556]
# [ 58.   59.1  60.2  61.3  62.4  63.5  64.6  65.7  66.8  67.9  69. ]
# [ 0.25925926  0.04938272  0.03703704  0.08641975  0.09876543  0.09876543
#   0.16049383  0.07407407  0.04938272  0.08641975]
# [ 58.   59.1  60.2  61.3  62.4  63.5  64.6  65.7  66.8  67.9  69. ]

# %%
##survivalstatus1(green) vs survival status2(red)
counts, bin_edges = np.histogram(hab_status1['p_axillary_nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color = 'green');
plt.plot(bin_edges[1:], cdf,color = 'green')


counts, bin_edges = np.histogram(hab_status2['p_axillary_nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,color='red');
plt.plot(bin_edges[1:], cdf,color = 'red')
plt.show();

#More than 80% of the survivals have less than 10 p_axillary_nodes
# Out:
# [ 0.83555556  0.08        0.02222222  0.02666667  0.01777778  0.00444444
#   0.00888889  0.          0.          0.00444444]
# [  0.    4.6   9.2  13.8  18.4  23.   27.6  32.2  36.8  41.4  46. ]
# [ 0.56790123  0.14814815  0.13580247  0.04938272  0.07407407  0.
#   0.01234568  0.          0.          0.01234568]
# [  0.    5.2  10.4  15.6  20.8  26.   31.2  36.4  41.6  46.8  52. ]

# %% [markdown]
# ### Boxplot

# %%
color_ordered = [u'#4daf4a', u'#e41a1c']

sns.boxplot(x= 'survival_status',y='age', palette=color_ordered,data = hab)
plt.show()
sns.boxplot(x= 'survival_status',y='year_of_operation', palette=color_ordered,data = hab)
plt.show()
sns.boxplot(x= 'survival_status',y='p_axillary_nodes', palette=color_ordered,data = hab)
plt.show()
#most of the survivals are between,ie IQR is between 45 to 60 years old.most of the survivals are between.ie IQR is between approx 47 to 62 years old
##we can see there are many outliers on survival data

# %% [markdown]
# ### Violin Plot

# %%
color_ordered = [u'#4daf4a', u'#e41a1c']

sns.violinplot(x= 'survival_status',y='age', palette=color_ordered,data = hab)
plt.show()
sns.violinplot(x= 'survival_status',y='year_of_operation', palette=color_ordered,data = hab)
plt.show()
sns.violinplot(x= 'survival_status',y='p_axillary_nodes', palette=color_ordered,data = hab)
plt.show()

# %%
print(hab['p_axillary_nodes'].value_counts())
print(hab_status1['p_axillary_nodes'].value_counts())
print(hab_status2['p_axillary_nodes'].value_counts())
# Out:
# 0     136
# 1      41
# 2      20
# 3      20
# 4      13
# 6       7
# 7       7
# 8       7
# 5       6
# 9       6
# 13      5
# 14      4
# 11      4
# 10      3
# 15      3
# 19      3
# 22      3
# 23      3
# 12      2
# 20      2
# 46      1
# 16      1
# 17      1
# 18      1
# 21      1
# 24      1
# 25      1
# 28      1
# 30      1
# 35      1
# 52      1
# Name: p_axillary_nodes, dtype: int64
# 0     117
# 1      33
# 2      15
# 3      13
# 4      10
# 7       5
# 8       5
# 6       4
# 14      3
# 10      2
# 22      2
# 5       2
# 9       2
# 46      1
# 11      1
# 30      1
# 13      1
# 15      1
# 16      1
# 18      1
# 19      1
# 20      1
# 25      1
# 28      1
# 12      1
# Name: p_axillary_nodes, dtype: int64
# 0     19
# 1      8
# 3      7
# 2      5
# 9      4
# 5      4
# 13     4
# 23     3
# 4      3
# 6      3
# 11     3
# 19     2
# 15     2
# 7      2
# 8      2
# 52     1
# 10     1
# 35     1
# 14     1
# 17     1
# 20     1
# 21     1
# ...

# %% [markdown]
# ### Contour Plot

# %%
sns.jointplot(x='age',y ='p_axillary_nodes', data = hab,kind = 'kde')
plt.show()
#All the age groups of have p_axillary_nodes zero or near to zero.

# %% [markdown]
# Conclusion:
# 1.	Haberman is an imbalanced dataset with survived patients of #225 and patients unable to survive within 5 years of #81
# 2.	By comparing mean,std dev of all the three features with corresponding median and mad,we can see p_axillary nodes show high difference in values.we can say p_axillary_nodes got outliers.Boxplot shows clearly the outliers of p_axillary_nodes in survival points.
# 3.	This looks like a messy dataset,if we can see the paiplots,we are not able to find any pattern.
# 4.	Highest number of survivals exist between 50 and 55,similarly 40 to 45 for unsurvived.
# 5.	Highest number of survivals had been operated between approx 60 to 61,similarly 63 to 66 for unsurvived.
# 6.	More than 50% of the survivals have n_axilliary_nodes as zero.As the n_axilliary_nodes increased survival rate drastically decreased.
# 7.	Most of the survivals are between,ie IQR is between 45 to 60 years old.most of the survivals are between.ie IQR is between approx 47 to 62 years old
# 8.	Most of the survivals are between 45 to 60 years old.most of the survivals are between approx 47 to 62 years old
# 9.	From Contout plot we can say,all the age groups have p_axillary_nodes zero or near to zero.
